# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

ratings_fin_data= pickle.load(open("ratings_AND_fin_data_ebit_ebitda_div_profit.p","rb"))

ratings_fin_data.head()
# Out:
#   ticker             Name       Sector         company  \
# 0    MMM       3M Company  Industrials              3M
# 1    MMM       3M Company  Industrials              3M
# 2    MMM       3M Company  Industrials              3M
# 3    MMM       3M Company  Industrials              3M
# 4    AOS  A.O. Smith Corp  Industrials  Smith A O Corp
#
#   financial year end (month) industry code   indicator Q1-2009 Q2-2009  \
# 0                         12        100001        EBIT     803    1191
# 1                         12        100001      EBITDA  1074.0  1489.0
# 2                         12        100001  Net Profit     518     783
# 3                         12        100001   Dividends    -354    -355
# 4                         12        100001        EBIT      16      33
#
#   Q3-2009       ...       Q1-2017 Q2-2017 Q3-2017 Q4-2017 Q1-2018 Q2-2018  \
# 0    1478       ...          1713    1723    2041    1757     983     NaN
# 1  1768.0       ...        2151.0  2103.0  2418.0  2106.0  1365.0     NaN
# 2     957       ...          1323    1583    1429     523     602     NaN
# 3    -361       ...          -702    -701    -701    -699    -810     NaN
# 4      46       ...           NaN     128     130     143     128     NaN
#
#   Q3-2018 missing data points (source) start date for uninterrupted values  \
# 0     NaN                            0                             Q1-2008
# 1     NaN                            0                             Q3-2008
# 2     NaN                            0                             Q1-2008
# 3     NaN                            0                             Q3-2008
# 4     NaN                            0                             Q1-2009
#
#   company_ratings
# 0             4.1
# 1             4.1
# 2             4.1
# 3             4.1
# 4             3.9
#
# [5 rows x 49 columns]

# %%
ticker_ratings_df = pd.DataFrame()
ticker_ratings_df["ticker"]  =  ratings_fin_data["ticker"]
ticker_ratings_df["company_ratings"] = ratings_fin_data["company_ratings"]
ticker_ratings_df.drop_duplicates().reset_index()
# Out:
#      index ticker company_ratings
# 0        0    MMM             4.1
# 1        4    AOS             3.9
# 2        8    ABT             4.1
# 3       12   ABBV             4.0
# 4       16    ACN             4.0
# 5       20   ATVI             3.8
# 6       24    AYI             3.6
# 7       28   ADBE             4.3
# 8       32    AAP             3.5
# 9       36    AMD             3.8
# 10      40    AES             4.1
# 11      44    AET             3.8
# 12      48    AMG             3.0
# 13      52    AFL             3.6
# 14      56      A             4.2
# 15      60    APD             3.9
# 16      64   AKAM             4.1
# 17      68    ALK             4.1
# 18      72    ALB             3.3
# 19      76    ARE             4.0
# 20      80   ALXN             3.4
# 21      84   ALGN             4.1
# 22      88   ALLE             3.8
# 23      92    AGN             3.8
# 24     100    ADS             3.8
# 25     104    LNT             3.4
# 26     108    ALL             3.8
# 27     112  GOOGL             3.8
# 28     113   GOOG             3.8
# 29     121     MO             4.2
# ..     ...    ...             ...
# 475   1855   VRTX             3.9
# 476   1859   VIAB             4.1
# 477   1863      V             4.0
# 478   1867    VNO             4.1
# 479   1871    VMC             3.7
# 480   1875    WMT             3.6
# 481   1879    WBA             3.5
# 482   1883     WM             3.5
# 483   1887    WAT             3.6
# 484   1891    WEC             3.8
# 485   1895    WFC             3.8
# 486   1899   WELL             4.0
# 487   1900    WDC             3.9
# 488   1904     WU             NaN
# 489   1908    WRK             3.4
# 490   1912     WY             3.9
# 491   1916    WHR             4.0
# 492   1920    WMB             NaN
# 493   1924   WLTW             3.8
# 494   1928    WYN             3.7
# 495   1932   WYNN             NaN
# 496   1936    XEL             3.7
# 497   1940    XRX             3.4
# 498   1944   XLNX             3.9
# 499   1948     XL             3.9
# 500   1949    XYL             3.6
# 501   1953    YUM             3.9
# 502   1957    ZBH             NaN
# 503   1961   ZION             3.7
# 504   1965    ZTS             3.7
#
# [505 rows x 3 columns]

# %%
# Barplot of ratings by company, not super informative
# though one interesting really high outlier

ticker_ratings_df.dtypes
ticker_ratings_df["company_ratings"] = ticker_ratings_df["company_ratings"].apply(pd.to_numeric)

ticker_ratings_df.plot.bar(x = "ticker" , y= "company_ratings")

# %%
high_scores = ticker_ratings_df[ticker_ratings_df["company_ratings"] >4.5]
print(high_scores)
# kind of weird when double checking...
# Out:
#     ticker  company_ratings
# 205    AIV              5.0
# 206    AIV              5.0
# 207    AIV              5.0
# 208    AIV              5.0

# %%
ticker_ratings_df.hist()

drop_dup_tick_ratings= ticker_ratings_df.drop_duplicates().reset_index()
# maybe normally distributed?
# or skewed, yea, seems skewed, leftward
# lots of responses in the 3.4/3.5/.6 range- cutoff around 4.3?
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1226ca518>]], dtype=object)

# %%
# previous hist forgot to drop duplicates
drop_dup_tick_ratings= ticker_ratings_df.drop_duplicates().reset_index()
drop_dup_tick_ratings.hist(column = "company_ratings", bins = 10)

# may want to transform?
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1217be240>]], dtype=object)

# %%
# calculate % increase as (ym1-y0)/ym1
import numpy as np
def percent_change(curr_year, last_year):
    if last_year == 0:
        return 0          # could also do a try with, else  thing here
    ans = ((curr_year-last_year)/last_year)
    return ans

# convert relevant columns to numeric
ratings_fin_data["Q1-2017"] = ratings_fin_data["Q1-2017"].apply(pd.to_numeric)
ratings_fin_data["Q1-2018"] = ratings_fin_data["Q1-2018"].apply(pd.to_numeric)


#attempt to vectorize, following below
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column/19976286
ratings_fin_data["percent_increase_2017Q1-2018Q1"] =np.vectorize(percent_change)(
    ratings_fin_data["Q1-2017"],ratings_fin_data["Q1-2018"])

# %%
print(ratings_fin_data.head())
print(ratings_fin_data.tail())
# Out:
#   ticker             Name       Sector         company  \
# 0    MMM       3M Company  Industrials              3M
# 1    MMM       3M Company  Industrials              3M
# 2    MMM       3M Company  Industrials              3M
# 3    MMM       3M Company  Industrials              3M
# 4    AOS  A.O. Smith Corp  Industrials  Smith A O Corp
#
#   financial year end (month) industry code   indicator Q1-2009 Q2-2009  \
# 0                         12        100001        EBIT     803    1191
# 1                         12        100001      EBITDA  1074.0  1489.0
# 2                         12        100001  Net Profit     518     783
# 3                         12        100001   Dividends    -354    -355
# 4                         12        100001        EBIT      16      33
#
#   Q3-2009              ...               Q2-2017 Q3-2017 Q4-2017 Q1-2018  \
# 0    1478              ...                  1723    2041    1757   983.0
# 1  1768.0              ...                2103.0  2418.0  2106.0  1365.0
# 2     957              ...                  1583    1429     523   602.0
# 3    -361              ...                  -701    -701    -699  -810.0
# 4      46              ...                   128     130     143   128.0
#
#   Q2-2018 Q3-2018 missing data points (source)  \
# 0     NaN     NaN                            0
# 1     NaN     NaN                            0
# 2     NaN     NaN                            0
# 3     NaN     NaN                            0
# 4     NaN     NaN                            0
#
#   start date for uninterrupted values company_ratings  \
# 0                             Q1-2008             4.1
# 1                             Q3-2008             4.1
# 2                             Q1-2008             4.1
# 3                             Q3-2008             4.1
# 4                             Q1-2009             3.9
#
#   percent_increase_2017Q1-2018Q1
# 0                       0.742625
# 1                       0.575824
# 2                       1.197674
# 3                      -0.133333
# 4                            NaN
#
# [5 rows x 50 columns]
#      ticker           Name       Sector        company  \
# 1964   ZION  Zions Bancorp   Financials  Zions Bancorp
# 1965    ZTS         Zoetis  Health Care         Zoetis
# 1966    ZTS         Zoetis  Health Care         Zoetis
# 1967    ZTS         Zoetis  Health Care         Zoetis
# 1968    ZTS         Zoetis  Health Care         Zoetis
#
#      financial year end (month) industry code   indicator Q1-2009 Q2-2009  \
# 1964                         12        104002   Dividends     -26     -25
# 1965                        NaN        106005        EBIT     NaN     NaN
# 1966                        NaN        106005      EBITDA     NaN     NaN
# 1967                        NaN        106005  Net Profit     NaN     NaN
# 1968                        NaN        106005   Dividends     NaN     NaN
#
#      Q3-2009              ...               Q2-2017 Q3-2017 Q4-2017 Q1-2018  \
# 1964     -23              ...                   -26     -34     NaN     NaN
# 1965     NaN              ...                   384     465     509   461.0
# 1966     NaN              ...                 443.0   523.0   572.0   521.0
# 1967     NaN              ...                   247     298      81   352.0
# 1968     NaN              ...                   -51     -52     -51   -62.0
#
#      Q2-2018 Q3-2018 missing data points (source)  \
# 1964     NaN     NaN                            0
# 1965     NaN     NaN                            0
# 1966     NaN     NaN                            0
# 1967     NaN     NaN                            0
# 1968     NaN     NaN                            0
#
#      start date for uninterrupted values company_ratings  \
# 1964                             Q1-2009             3.7
# 1965                             Q1-2012             3.7
# 1966                             Q1-2012             3.7
# 1967                             Q1-2012             3.7
# 1968                             Q1-2012             3.7
#
#      percent_increase_2017Q1-2018Q1
# 1964                            NaN
# 1965                            NaN
# 1966                            NaN
# 1967                            NaN
# 1968                       -0.16129
#
# [5 rows x 50 columns]

# %%
#filter only for profit data
ratings_fin_data_profit_increase_only = ratings_fin_data[ratings_fin_data["indicator"] =="Net Profit"]

 
#ratings_fin_data.hist(columns = "percent_increase_2017Q1-2018Q1")
# Out:
#      ticker                                 Name                      Sector  \
# 2       MMM                           3M Company                 Industrials
# 6       AOS                      A.O. Smith Corp                 Industrials
# 10      ABT                  Abbott Laboratories                 Health Care
# 14     ABBV                          AbbVie Inc.                 Health Care
#
#                                   company financial year end (month)  \
# 2                                      3M                         12
# 6                          Smith A O Corp                         12
# 10                    ABBOTT LABORATORIES                         12
# 14                            AbbVie Inc.                        NaN
# 18                          Accenture plc                        NaN
# 22                    Activision Blizzard                         12
# 26                      ACUITY BRANDS INC                          8
# 30                      ADOBE SYSTEMS INC                         12
# 34                 ADVANCE AUTO PARTS INC                        NaN
# 38             ADVANCED MICRO DEVICES INC                         12
# 42                               AES CORP                         12
# 46                         AETNA INC /PA/                         12
# 50        AFFILIATED MANAGERS GROUP, INC.                         12
# 54                              AFLAC INC                         12
# 58               AGILENT TECHNOLOGIES INC                         10
# 62      AIR PRODUCTS & CHEMICALS INC /DE/                          9
# 66                AKAMAI TECHNOLOGIES INC                         12
# 70                 ALASKA AIR GROUP, INC.                         12
# 74                         ALBEMARLE CORP                         12
# 78    Alexandria Real Estate Equities Inc                         12
# 82            ALEXION PHARMACEUTICALS INC                         12
# 86                   Align Technology Inc                         12
# 90                           Allegion plc                        NaN
# 94                          Allergan Inc.                         12
# 98                           Allergan plc                        NaN
# 102            ALLIANCE DATA SYSTEMS CORP                         12
# 106                   ALLIANT ENERGY CORP                         12
# 110                         ALLSTATE CORP                         12
# 115                              Alphabet                        NaN
# 119                           Google Inc.                        NaN
# ...                                   ...                        ...
# 1849                     Verisk Analytics                        NaN
# 1853           VERIZON COMMUNICATIONS INC                         12
# 1857      VERTEX PHARMACEUTICALS INC / MA                         12
# 1861                          Viacom Inc.                        NaN
# 1865                            VISA INC.                        NaN
# 1869                 Vornado Realty Trust                         12
# 1873                     Vulcan Materials                        NaN
# 1877                  WAL MART STORES INC                          1
# 1881       Walgreens Boots Alliance, Inc.                        NaN
# 1885                Waste Management Inc.                         12
# 1889                   Waters Corporation                         12
# 1893         Wisconsin Energy Corporation                         12
# 1897             WELLS FARGO & COMPANY/MN                         12
# 1902                 WESTERN DIGITAL CORP                          6
# 1906                     Western Union Co                        NaN
# 1910                          WestRock Co                        NaN
# 1914                      WEYERHAEUSER CO                         12
# 1918                  WHIRLPOOL CORP /DE/                         12
# 1922               WILLIAMS COMPANIES INC                         12
# 1926                 Willis Towers Watson                         12
# 1930               WYNDHAM WORLDWIDE CORP                        NaN
# 1934                     Wynn Resorts Ltd                        NaN
# 1938                      Xcel Energy Inc                         12
# 1942                          Xerox Corp.                         12
# 1946                           XILINX INC                          4
# 1951                           Xylem Inc.                        NaN
# 1955                       YUM BRANDS INC                         12
# 1959               Zimmer Biomet Holdings                         12
# 1963                        Zions Bancorp                         12
# 1967                               Zoetis                        NaN
#
#      industry code   indicator Q1-2009 Q2-2009 Q3-2009  \
# 2           100001  Net Profit     518     783     957
# 6           100001  Net Profit       2      21      34
# 10          106004  Net Profit    1438    1288    1480
# 14          106005  Net Profit     NaN     NaN     NaN
# 18          108002  Net Profit     479     411     443
# 22          101003  Net Profit     189     195      15
# 26          101001  Net Profit     NaN     NaN     NaN
# 30          101003  Net Profit     156     126     136
# 34          103002  Net Profit      93      80      61
# 38          101004  Net Profit    -416    -330    -128
# 42          105001  Net Profit     218     303     185
# 46          106006  Net Profit     437     346     326
# 50          104001  Net Profit       6      10      17
# 54          104004  Net Profit     569     314     363
# 58          106001  Net Profit      64    -101     -19
# 62          110001  Net Profit      68     205     113
# 66          101003  Net Profit      37      36      32
# 70          100006  Net Profit     -20      29      87
# 74          110001  Net Profit      25      38      52
# 78          109001  Net Profit      32      32      18
# 82          106002  Net Profit      14      16      26
# 86          106004  Net Profit       2       4     -50
# 90          100007  Net Profit     NaN     NaN     NaN
# 94          106005  Net Profit      44     176     179
# 98          106005  Net Profit     NaN     NaN     NaN
# 102         104007  Net Profit      27      29      45
# 106         105001  Net Profit      72      29     -45
# 110         104006  Net Profit    -274     389     221
# 115         101002  Net Profit     NaN     NaN     NaN
# 119         101002  Net Profit    1423    1485    1639
# ...            ...         ...     ...     ...     ...
# 1849        100002  Net Profit     NaN     NaN     NaN
# 1853        108001  Net Profit    1645    1483    1176
# 1857        106002  Net Profit    -163    -172    -150
# 1861        103001  Net Profit     177     277     463
# 1865        104007  Net Profit     574     536     731
# 1869        109001  Net Profit     125     -52     126
# 1873        110005  Net Profit     -33      22      54
# 1877        102001  Net Profit    3022    3472    3144
# 1881        102001  Net Profit     NaN     NaN     NaN
# 1885        100004  Net Profit     155     247     277
# 1889        106003  Net Profit      73      69      75
# 1893        105001  Net Profit     141      63      58
# 1897        104002  Net Profit    2384    2575    2637
# 1902        101001  Net Profit     211      14      50
# 1906        104007  Net Profit     223     220     181
# 1910        103018  Net Profit     NaN     NaN     NaN
# 1914        110002  Net Profit     NaN     NaN     NaN
# 1918        103004  Net Profit      68      78      87
# 1922        107003  Net Profit    -172     140     145
# 1926        104003  Net Profit     193      87      79
# 1930        103015  Net Profit      45      71     104
# 1934        103015  Net Profit     -34      25      34
# 1938        105001  Net Profit     173     116     219
# 1942        101003  Net Profit      42     140     123
# 1946        101004  Net Profit      38      64     106
# 1951        100001  Net Profit     NaN     NaN     NaN
# 1955        103003  Net Profit     218     303     334
# 1959        106004  Net Profit     202     210     149
# 1963        104002  Net Profit    -853     -24    -182
# 1967        106005  Net Profit     NaN     NaN     NaN
#
#                   ...               Q2-2017 Q3-2017 Q4-2017 Q1-2018 Q2-2018  \
# 2                 ...                  1583    1429     523   602.0     NaN
# 6                 ...                    92      93      22    98.0     NaN
# 10                ...                   283     603    -828   418.0     NaN
# 14                ...                   NaN    1631     NaN     NaN     NaN
# 18                ...                   NaN     669     932  1123.0     NaN
# 22                ...                   NaN     188    -584   500.0     NaN
# 26                ...                    67      82      90    71.0     NaN
# 30                ...                   374     419     501   583.0     NaN
# 34                ...                    87      95     NaN     NaN     NaN
# 38                ...                   -16      71      21    81.0     NaN
# 38       NaN                            0                             Q1-2009
# 42       NaN                            0                             Q1-2008
# 46       NaN                            0                             Q1-2008
# 50       NaN                            0                             Q1-2009
# 54       NaN                            0                             Q1-2008
# 58       NaN                            0                             Q3-2008
# 62       NaN                            0                             Q1-2009
# 66       NaN                            0                             Q1-2008
# 70       NaN                            0                             Q1-2009
# 74       NaN                            0                             Q1-2009
# 78       NaN                            0                             Q1-2009
# 82       NaN                            0                             Q1-2009
# 86       NaN                            0                             Q1-2009
# 90       NaN                            0                             Q1-2013
# 94       NaN                            0                             Q1-2008
# 98       NaN                            0                             Q1-2013
# 102      NaN                            0                             Q1-2009
# 106      NaN                            0                             Q1-2009
# 110      NaN                            0                             Q1-2008
# 115      NaN                            0                             Q3-2014
# 119      NaN                            0                             Q1-2008
# ...      ...                          ...                                 ...
# 1849     NaN                            0                             Q1-2010
# 1853     NaN                            0                             Q1-2008
# 1857     NaN                            0                             Q1-2009
# 1861     NaN                            0                             Q1-2008
# 1865     NaN                            0                             Q3-2008
# 1869     NaN                            0                             Q3-2008
# 1873     NaN                            0                             Q1-2008
# 1877     NaN                            0                             Q1-2008
# 1881     NaN                            0                             Q1-2014
# 1885     NaN                            0                             Q3-2008
# 1889     NaN                            0                             Q1-2008
# 1893     NaN                            0                             Q1-2008
# 1897     NaN                            0                             Q1-2008
# 1902     NaN                            0                             Q1-2009
# 1906     NaN                            0                             Q1-2008
# 1910     NaN                            0                             Q1-2015
# 1914     NaN                            0                             Q1-2010
# 1918     NaN                            0                             Q1-2009
# 1922     NaN                            0                             Q1-2008
# 1926     NaN                            0                             Q1-2009
# 1930     NaN                            0                             Q1-2009
# 1934     NaN                            0                             Q1-2009
# 1938     NaN                            0                             Q1-2008
# 1942     NaN                            0                             Q1-2008
# 1946     NaN                            0                             Q1-2009
# 1951     NaN                            0                             Q3-2010
# 1955     NaN                            0                             Q3-2008
# 1959     NaN                            0                             Q1-2008
# 1963     NaN                            0                             Q1-2009
# 1967     NaN                            0                             Q1-2012
#
#      company_ratings percent_increase_2017Q1-2018Q1
# 2                4.1                       1.197674
# 6                3.9                            NaN
# 10               4.1                       0.002392
# 14               4.0                            NaN
# 18               4.0                      -0.105966
# 22               3.8                      -0.148000
# 26               3.6                       0.140845
# 30               4.3                      -0.317324
# 34               3.5                            NaN
# 38               3.8                            NaN
# 42               4.1                            NaN
# 46               3.8                            NaN
# 50               3.0                            NaN
# 54               3.6                      -0.174338
# 58               4.2                      -1.525000
# 62               3.9                            NaN
# 66               4.1                            NaN
# 70               4.1                            NaN
# 74               3.3                            NaN
# 78               4.0                            NaN
# 82               3.4                      -0.317269
# 86               4.1                            NaN
# 90               3.8                            NaN
# 94               3.8                            NaN
# 98               3.8                            NaN
# 102              3.8                            NaN
# 106              3.4                            NaN
# 110              3.8                      -0.295983
# 115              3.8                      -0.422827
# 119              3.8                            NaN
# ...              ...                            ...
# 1849             3.8                            NaN
# 1853             3.9                            NaN
# 1857             3.9                            NaN
# 1861             4.1                            NaN
# 1865             4.0                      -0.179223
# 1869             4.1                      -3.611111
# 1873             3.7                            NaN
# 1877             3.6                            NaN
# 1881             3.5                            NaN
# 1885             3.5                            NaN
# 1889             3.6                      -0.054054
# 1893             3.8                            NaN
# 1897             3.8                            NaN
# 1902             3.9                      -1.537445
# 1906             NaN                            NaN
# 1910             3.4                            NaN
# 1914             3.9                            NaN
# 1918             4.0                            NaN
# 1922             NaN                            NaN
# 1926             3.8                            NaN
# 1930             3.7                            NaN
# 1934             NaN                            NaN
# 1938             3.7                            NaN
# 1942             3.4                            NaN
# 1946             3.9                            NaN
# 1951             3.6                            NaN
# 1955             3.9                            NaN
# 1959             NaN                            NaN
# 1963             3.7                            NaN
# 1967             3.7                            NaN
#
# [484 rows x 50 columns]

# %%
#check for null values
print(ratings_fin_data_profit_increase_only["Q1-2017"].isnull().sum() )
print(ratings_fin_data_profit_increase_only["Q1-2018"].isnull().sum())
print (ratings_fin_data_profit_increase_only["percent_increase_2017Q1-2018Q1"].isnull().sum())
# null vals for above
#166
#269
#351
#Why aren't these nulls adding up?
# some overlap?
# Out:
# 166
# 269
# 351

# %%
ratings_fin_data_profit_increase_only.hist(column = "percent_increase_2017Q1-2018Q1")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1200a6358>]], dtype=object)

# %%
df_for_correlation_year_profit_ratings = pd.DataFrame()
df_for_correlation_year_profit_ratings["percent_increase"] = ratings_fin_data_profit_increase_only["percent_increase_2017Q1-2018Q1"]
df_for_correlation_year_profit_ratings["company_ratings"] = ratings_fin_data_profit_increase_only["company_ratings"].apply(pd.to_numeric)
df_for_correlation_year_profit_ratings.corr()
# Out:
#                   percent_increase  company_ratings
# percent_increase          1.000000        -0.004186
# company_ratings          -0.004186         1.000000

# %%
def list_nulls_year(year_s, df):
    null_dict = {}
    for i in range(1,5):
        q = "Q{}-".format(i)
        qyear = q+year_s
        nulls = df[qyear].isnull().sum()
        null_dict[qyear] = nulls
        
    return(null_dict)

def list_nulls_2018(year_s, df):  #special bc no q4
    null_dict = {}
    for i in range(1,4):
        q = "Q{}-".format(i)
        qyear = q+year_s
        nulls = df[qyear].isnull().sum()
        null_dict[qyear] = nulls
    return(null_dict)
    
null_16 = list_nulls_year("2016",ratings_fin_data_profit_increase_only)
print(null_16)

null_17 = list_nulls_year("2017",ratings_fin_data_profit_increase_only)
print(null_17)

null_18 = list_nulls_2018("2018",ratings_fin_data_profit_increase_only)
print(null_18)

        
        
# looking at the lists of Nulls, a time span with low potential nulls relative to the group
# is Q2 2016 to Q2 2017
# Out:
# {'Q2-2016': 92, 'Q1-2016': 81, 'Q3-2016': 114, 'Q4-2016': 28}
# {'Q3-2017': 76, 'Q4-2017': 155, 'Q2-2017': 65, 'Q1-2017': 166}
# {'Q1-2018': 269, 'Q2-2018': 470, 'Q3-2018': 481}
